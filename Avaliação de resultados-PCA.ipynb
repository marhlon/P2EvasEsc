# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
metodos = ['GaussianNB()', 'LogisticRegression()', 'KNeighborsClassifier()', 'KNeighborsClassifier(n_neighbors=10)',
           'SVC()', 'SVC(C=100, gamma=0.01)', 'DecisionTreeClassifier()', 'DecisionTreeClassifier(max_depth=2)',
           'RandomForestClassifier()', 'RandomForestClassifier(n_estimators=4)', 'MLPClassifier()',
           'MLPClassifier(max_iter=5)']

avaliacoes = ['Acuracia_Teste', 'Acuracia_Treino', 'Precisao_Teste', 'Precisao_Treino','F1_Teste', 'F1_Treino']

db0 = pd.read_csv('Relatorio/PCA/classification_report_{}.csv'.format(str(metodos[0])))
db1 = pd.read_csv('Relatorio/PCA/classification_report_{}.csv'.format(str(metodos[1])))
db2 = pd.read_csv('Relatorio/PCA/classification_report_{}.csv'.format(str(metodos[2])))
db3 = pd.read_csv('Relatorio/PCA/classification_report_{}.csv'.format(str(metodos[3])))
db4 = pd.read_csv('Relatorio/PCA/classification_report_{}.csv'.format(str(metodos[4])))
db5 = pd.read_csv('Relatorio/PCA/classification_report_{}.csv'.format(str(metodos[5])))
db6 = pd.read_csv('Relatorio/PCA/classification_report_{}.csv'.format(str(metodos[6])))
db7 = pd.read_csv('Relatorio/PCA/classification_report_{}.csv'.format(str(metodos[7])))
db8 = pd.read_csv('Relatorio/PCA/classification_report_{}.csv'.format(str(metodos[8])))
db9 = pd.read_csv('Relatorio/PCA/classification_report_{}.csv'.format(str(metodos[9])))
db10 = pd.read_csv('Relatorio/PCA/classification_report_{}.csv'.format(str(metodos[10])))
db11 = pd.read_csv('Relatorio/PCA/classification_report_{}.csv'.format(str(metodos[11])))

# %%
db0.head()
# Out:
#    Acuracia_Teste  Acuracia_Treino  Precisao_Teste  Precisao_Treino  F1_Teste  \
# 0        0.623656         0.694444        0.633333         0.737500  0.520548
# 1        0.580645         0.708333        0.642857         0.746667  0.480000
# 2        0.677419         0.731481        0.896552         0.750000  0.634146
# 3        0.623656         0.708333        0.647059         0.774648  0.556962
# 4        0.698925         0.722222        0.627907         0.735294  0.658537
#
#    F1_Treino
# 0   0.641304
# 1   0.640000
# 2   0.650602
# 3   0.635838
# 4   0.714286

# %%
metleg = ['NB', 'RegLog', 'KNN', 'KNN(BP*)', 'SVC', 'SVC(BP*)', 'ArvClas', 'ArvClas(BP*)', 'RanFor', 'RanFor(BP*)', 'ANN', 'ANN(BP*)']

# %%
legenda = ['NB', 'RegLog', 'KNN', 'KNN(BP*)', 'SVC', 'SVC(BP*)', 'ArvClas', 'ArvClas(BP*)', 'RanFor', 'RanFor(BP*)', 'ANN', 'ANN(BP*)', 'Classe']

# %%
mediasCalc = []
mediasTest = []
mediasTrain = []
AcuraciaTe = []
AcuraciaTr = []
PrecisaoTe = []
PrecisaoTr = []
F1Te = []
F1Tr = []

# %%
def calcMedia(database):
    for i in range(0,len(avaliacoes)):
        mediasCalc.append(database.mean()[i])
        
def mediaMatrizTest(database):
    for i in range(0,4):
        mediasTest.append(database.mean()[i])

def mediaMatrizTrain(database):
    for i in range(0,4):
        mediasTrain.append(database.mean()[i])
        
def incluirDados(database):
    for i in range(0, len(database['Acuracia_Teste'])):
        AcuraciaTe.append(database['Acuracia_Teste'][i])
    for i in range(0, len(database['Acuracia_Teste'])):
        AcuraciaTr.append(database['Acuracia_Treino'][i])
    for i in range(0, len(database['Precisao_Teste'])):
        PrecisaoTe.append(database['Precisao_Teste'][i])
    for i in range(0, len(database['Precisao_Treino'])):
        PrecisaoTr.append(database['Precisao_Treino'][i])
    for i in range(0, len(database['F1_Teste'])):
        F1Te.append(database['F1_Teste'][i])
    for i in range(0, len(database['F1_Treino'])):
        F1Tr.append(database['F1_Treino'][i])

# %%
incluirDados(db0)
incluirDados(db1)
incluirDados(db2)
incluirDados(db3)
incluirDados(db4)
incluirDados(db5)
incluirDados(db6)
incluirDados(db7)
incluirDados(db8)
incluirDados(db9)
incluirDados(db10)
incluirDados(db11)

# %%
calcMedia(db0)
calcMedia(db1)
calcMedia(db2)
calcMedia(db3)
calcMedia(db4)
calcMedia(db5)
calcMedia(db6)
calcMedia(db7)
calcMedia(db8)
calcMedia(db9)
calcMedia(db10)
calcMedia(db11)

# %%
mediasCalc = pd.DataFrame(data=np.reshape(mediasCalc, (12,6)), index=metodos, columns=avaliacoes)
medias

# %%
AcuraciaTe = pd.DataFrame(data=np.reshape(AcuraciaTe, (12,30)))
AcuraciaTe = AcuraciaTe.T
AcuraciaTe.columns = metleg
AcuraciaTr = pd.DataFrame(data=np.reshape(AcuraciaTr, (12,30)))
AcuraciaTr = AcuraciaTr.T
AcuraciaTr.columns = metleg

# %%
AcuraciaTe
# Out:
#           NB    RegLog       KNN  KNN(BP*)       SVC  SVC(BP*)   ArvClas  \
# 0   0.623656  0.655914  0.709677  0.731183  0.698925  0.645161  0.548387
# 1   0.580645  0.645161  0.752688  0.731183  0.688172  0.720430  0.698925
# 2   0.677419  0.677419  0.666667  0.623656  0.677419  0.720430  0.698925
# 3   0.623656  0.731183  0.752688  0.720430  0.731183  0.741935  0.602151
# 4   0.698925  0.709677  0.741935  0.698925  0.774194  0.741935  0.612903
# 5   0.677419  0.698925  0.688172  0.666667  0.688172  0.655914  0.677419
# 6   0.720430  0.720430  0.612903  0.698925  0.709677  0.709677  0.580645
# 7   0.602151  0.645161  0.677419  0.645161  0.612903  0.688172  0.612903
# 8   0.666667  0.677419  0.688172  0.698925  0.763441  0.731183  0.602151
# 9   0.666667  0.612903  0.688172  0.666667  0.655914  0.774194  0.602151
# 10  0.645161  0.709677  0.720430  0.698925  0.709677  0.677419  0.655914
# 11  0.645161  0.709677  0.709677  0.741935  0.677419  0.741935  0.612903
# 12  0.655914  0.709677  0.677419  0.677419  0.709677  0.655914  0.612903
# 13  0.709677  0.741935  0.731183  0.774194  0.731183  0.795699  0.741935
# 14  0.666667  0.655914  0.666667  0.688172  0.698925  0.731183  0.634409
# 15  0.688172  0.731183  0.688172  0.688172  0.698925  0.688172  0.612903
# 16  0.677419  0.655914  0.731183  0.688172  0.688172  0.677419  0.580645
# 17  0.720430  0.698925  0.752688  0.698925  0.720430  0.774194  0.698925
# 18  0.688172  0.634409  0.666667  0.763441  0.720430  0.752688  0.623656
# 19  0.677419  0.655914  0.677419  0.677419  0.677419  0.720430  0.634409
#     Acuracia_Teste  Acuracia_Treino  Precisao_Teste  Precisao_Treino  \
# 0         0.623656         0.694444        0.633333         0.737500
# 1         0.580645         0.708333        0.642857         0.746667
# 2         0.677419         0.731481        0.896552         0.750000
# 3         0.623656         0.708333        0.647059         0.774648
# 4         0.698925         0.722222        0.627907         0.735294
# 5         0.677419         0.712963        0.631579         0.736842
# 6         0.720430         0.726852        0.717949         0.718447
# 7         0.602151         0.722222        0.689655         0.800000
# 8         0.666667         0.694444        0.694444         0.719512
# 9         0.666667         0.722222        0.727273         0.673077
# 10        0.645161         0.726852        0.687500         0.752941
# 11        0.645161         0.712963        0.636364         0.772152
# 12        0.655914         0.703704        0.510638         0.727273
# 13        0.709677         0.717593        0.810811         0.725000
# 14        0.666667         0.726852        0.675676         0.744444
# 15        0.688172         0.712963        0.727273         0.753086
# 16        0.677419         0.722222        0.577778         0.760417
# 17        0.720430         0.726852        0.743590         0.752941
# 18        0.688172         0.722222        0.619048         0.740000
# 19        0.677419         0.717593        0.733333         0.762500
# 20        0.623656         0.699074        0.611111         0.734940
# 21        0.655914         0.703704        0.565217         0.706422
# 22        0.677419         0.726852        0.666667         0.683761
# 23        0.731183         0.689815        0.736842         0.707865
# 24        0.677419         0.736111        0.642857         0.744898
# 25        0.634409         0.726852        0.585366         0.770115
# 26        0.666667         0.712963        0.718750         0.743902
# 27        0.688172         0.717593        0.714286         0.744186
# 28        0.688172         0.648148        0.733333         0.689189
# 29        0.688172         0.726852        0.694444         0.747253
#
#     F1_Teste  F1_Treino
# 0   0.520548   0.641304
# 1   0.480000   0.640000
# 2   0.634146   0.650602
# 3   0.556962   0.635838
# 4   0.658537   0.714286
# 5   0.615385   0.693069
# 6   0.682927   0.714976
# 7   0.519481   0.634146
# 8   0.617284   0.641304
# 9   0.673684   0.700000
# 10  0.571429   0.684492
# 11  0.560000   0.663043
# 12  0.600000   0.714286
# 13  0.689655   0.655367
# 14  0.617284   0.694301
# 15  0.623377   0.663043
# 16  0.634146   0.708738
# 17  0.690476   0.684492
# 18  0.641975   0.711538
# 19  0.594595   0.666667
# 20  0.556962   0.652406
# 21  0.619048   0.706422
# 22  0.666667   0.730594
# 23  0.691358   0.652850
# 24  0.642857   0.719212
# 25  0.585366   0.694301
# 26  0.597403   0.663043
# 27  0.632911   0.677249
# 28  0.602740   0.573034
# 29  0.632911   0.697436

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure(figsize =(12, 7))

bpl = plt.boxplot(AcuraciaTe.T, positions=np.array(range(len(AcuraciaTe.T)))*2.0-0.4, sym='', widths=0.7)
bpr = plt.boxplot(AcuraciaTr.T, positions=np.array(range(len(AcuraciaTr.T)))*2.0+0.4, sym='', widths=0.7)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Teste')
plt.plot([], c='#2C7BB6', label='Treino')
plt.legend()

plt.xticks(range(0, len(metleg) * 2, 2), metleg)
plt.xlim(-2, len(metleg)*2)
plt.title("Acurácia")
plt.xlabel("Método")
plt.ylabel("Percentual")

plt.savefig('BPAcuracia.jpeg')

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure(figsize =(12, 7))

bpl = plt.boxplot(PrecisaoTe.T, positions=np.array(range(len(PrecisaoTe.T)))*2.0-0.4, sym='', widths=0.7)
bpr = plt.boxplot(PrecisaoTr.T, positions=np.array(range(len(PrecisaoTr.T)))*2.0+0.4, sym='', widths=0.7)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Teste')
plt.plot([], c='#2C7BB6', label='Treino')
plt.legend()

plt.xticks(range(0, len(metleg) * 2, 2), metleg)
plt.xlim(-2, len(metleg)*2)
plt.title("Precisão")
plt.xlabel("Método")
plt.ylabel("Percentual")

plt.savefig('BPPrecisao.jpeg')

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure(figsize =(12, 7))

bpl = plt.boxplot(F1Te.T, positions=np.array(range(len(F1Te.T)))*2.0-0.4, sym='', widths=0.7)
bpr = plt.boxplot(F1Tr.T, positions=np.array(range(len(F1Tr.T)))*2.0+0.4, sym='', widths=0.7)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Teste')
plt.plot([], c='#2C7BB6', label='Treino')
plt.legend()

plt.xticks(range(0, len(metleg) * 2, 2), metleg)
plt.xlim(-2, len(metleg)*2)
plt.title("Precisão")
plt.xlabel("Método")
plt.ylabel("Percentual")

plt.savefig('BPF1.jpeg')

# %%
fig = plt.figure(figsize =(12, 7))
ax = fig.add_subplot()
plt.boxplot(db11.T)

plt.title("BoxPlot Testes")
plt.xlabel("Teste")
plt.ylabel("Percentual")
ax.set_xticklabels(metleg)
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot()
plt.boxplot(AcuraciaTe.T)

plt.title("BoxPlot Testes")
#plt.xlabel("Teste")
#plt.ylabel("Percentual")
#ax.set_xticklabels(avaliacoes)
plt.show()

# %%
plt.figure(figsize=(12,8))

barWidth = 0.15

r1 = np.arange(len(mediasCalc.index))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]
r6 = [x + barWidth for x in r5]

plt.bar(r1, mediasCalc['Acuracia_Teste'], color="#A637F0", width=barWidth, label="Acurácia Teste")
plt.bar(r2, mediasCalc['Acuracia_Treino'], color="#5A19FA", width=barWidth, label="Acurácia Treino")
plt.bar(r3, mediasCalc['Precisao_Teste'], color="#1B22E0", width=barWidth, label="Precisão Teste")
plt.bar(r4, mediasCalc['Precisao_Treino'], color="#1160F7", width=barWidth, label="Precisão Treino")
plt.bar(r5, mediasCalc['F1_Teste'], color="#119FED", width=barWidth, label="F1 Teste")
plt.bar(r6, mediasCalc['F1_Treino'], color="#14CEF0", width=barWidth, label="F1 Treino")

plt.xlabel('Métodos')
plt.xticks([r + barWidth for r in range(len(mediasCalc.index))], metleg)
plt.ylabel('Percentual')
plt.title('Avaliação dos Scores')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))

barWidth = 0.15

r1 = np.arange(len(db1.index))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]
r6 = [x + barWidth for x in r5]

plt.bar(r1, db1['Acuracia_Teste'], color="#A637F0", width=barWidth, label="Acurácia Teste")
plt.bar(r2, db1['Acuracia_Treino'], color="#5A19FA", width=barWidth, label="Acurácia Treino")
plt.bar(r3, db1['Precisao_Teste'], color="#1B22E0", width=barWidth, label="Precisão Teste")
plt.bar(r4, db1['Precisao_Treino'], color="#1160F7", width=barWidth, label="Precisão Treino")
plt.bar(r5, db1['F1_Teste'], color="#119FED", width=barWidth, label="F1 Teste")
plt.bar(r6, db1['F1_Treino'], color="#14CEF0", width=barWidth, label="F1 Treino")

plt.xlabel('Métodos')
plt.xticks(range(0,30))
plt.ylabel('Percentual')
plt.title('Avaliação dos Scores')

plt.legend()
plt.show()

# %%
db11.mean()

# %%
db11.min()

# %%
db11.max()
